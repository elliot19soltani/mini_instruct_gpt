# %%
import warnings
warnings.filterwarnings("ignore")
from torch import multiprocessing
import torch.nn as nn
    

from collections import defaultdict

import matplotlib.pyplot as plt
import torch
from tensordict.nn import TensorDictModule
from tensordict.nn.distributions import NormalParamExtractor
from torch import nn
from torchrl.collectors import SyncDataCollector
from torchrl.data.replay_buffers import ReplayBuffer
from torchrl.data.replay_buffers.samplers import SamplerWithoutReplacement
from torchrl.data.replay_buffers.storages import LazyTensorStorage
from torchrl.envs import (Compose, DoubleToFloat, ObservationNorm, StepCounter,
                          TransformedEnv)
from torchrl.envs.libs.gym import GymEnv
from torchrl.envs.utils import check_env_specs, ExplorationType, set_exploration_type
from torchrl.modules import ProbabilisticActor, TanhNormal, ValueOperator
from torchrl.objectives import ClipPPOLoss
from torchrl.objectives.value import GAE
from tqdm import tqdm

# %%
import gymnasium as gym

[
    print(game_env)
    for game_env in list(gym.envs.registry.keys())
];
# Out:
# CartPole-v0
# CartPole-v1
# MountainCar-v0
# MountainCarContinuous-v0
# Pendulum-v1
# Acrobot-v1
# phys2d/CartPole-v0
# phys2d/CartPole-v1
# phys2d/Pendulum-v0
# LunarLander-v3
# LunarLanderContinuous-v3
# BipedalWalker-v3
# BipedalWalkerHardcore-v3
# CarRacing-v3
# Blackjack-v1
# FrozenLake-v1
# FrozenLake8x8-v1
# CliffWalking-v1
# CliffWalkingSlippery-v1
# Taxi-v3
# tabular/Blackjack-v0
# tabular/CliffWalking-v0
# Reacher-v2
# Reacher-v4
# Reacher-v5
# Pusher-v2
# Pusher-v4
# Pusher-v5
# InvertedPendulum-v2
# InvertedPendulum-v4
# InvertedPendulum-v5
# InvertedDoublePendulum-v2
# InvertedDoublePendulum-v4
# InvertedDoublePendulum-v5
# HalfCheetah-v2
# HalfCheetah-v3
# HalfCheetah-v4
# HalfCheetah-v5
# Hopper-v2
# Hopper-v3
# Hopper-v4
# Hopper-v5
# Swimmer-v2
# Swimmer-v3
# Swimmer-v4
# Swimmer-v5
# Walker2d-v2
# Walker2d-v3
# Walker2d-v4
# Walker2d-v5
# Ant-v2
# Ant-v3
# Ant-v4
# Ant-v5
# Humanoid-v2
# Humanoid-v3
# Humanoid-v4
# Humanoid-v5
# HumanoidStandup-v2
# HumanoidStandup-v4
# HumanoidStandup-v5
# GymV21Environment-v0
# GymV26Environment-v0

# %%
from torchrl.envs import (Compose, DoubleToFloat, ObservationNorm, StepCounter,
                          TransformedEnv, set_exploration_type)

dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(dev)

base_env = GymEnv("InvertedDoublePendulum-v4", device=dev)
env = TransformedEnv(
    base_env, 
    Compose(
        # normalize observations
        ObservationNorm(in_keys=["observation"]),
        DoubleToFloat(),
        StepCounter(),
    )
)
env.transform[0].init_stats(num_iter=1000, reduce_dim=0, cat_dim=0)
obsv=  env.reset()
obsv
# Out:
# cuda
# TensorDict(
#     fields={
#         done: Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         observation: Tensor(shape=torch.Size([11]), device=cuda:0, dtype=torch.float32, is_shared=True),
#         step_count: Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.int64, is_shared=True),
#         terminated: Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         truncated: Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#     batch_size=torch.Size([]),
#     device=cuda:0,
#     is_shared=True)

# %%
print("observation_spec:", env.observation_spec)
print("reward_spec:", env.reward_spec)
print("input_spec:", env.input_spec)
print("action_spec (as defined by input_spec):", env.action_spec)
# Out:
# observation_spec: Composite(
#     observation: UnboundedContinuous(
#         shape=torch.Size([11]),
#         space=ContinuousBox(
#             low=Tensor(shape=torch.Size([11]), device=cuda:0, dtype=torch.float32, contiguous=True),
#             high=Tensor(shape=torch.Size([11]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#         device=cuda:0,
#         dtype=torch.float32,
#         domain=continuous),
#     step_count: BoundedDiscrete(
#         shape=torch.Size([1]),
#         space=ContinuousBox(
#             low=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.int64, contiguous=True),
#             high=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.int64, contiguous=True)),
#         device=cuda:0,
#         dtype=torch.int64,
#         domain=discrete),
#     device=cuda:0,
#     shape=torch.Size([]),
#     data_cls=None)
# reward_spec: UnboundedContinuous(
#     shape=torch.Size([1]),
#     space=ContinuousBox(
#         low=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#         high=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#     device=cuda:0,
#     dtype=torch.float32,
#     domain=continuous)
# input_spec: Composite(
#     full_state_spec: Composite(
#         step_count: BoundedDiscrete(
#             shape=torch.Size([1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.int64, contiguous=True),
#                 high=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.int64, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.int64,
#             domain=discrete),
#         device=cuda:0,
#         shape=torch.Size([]),
#         data_cls=None),
#     full_action_spec: Composite(
#         action: BoundedContinuous(
#             shape=torch.Size([1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([]),
#     data_cls=None)
# action_spec (as defined by input_spec): BoundedContinuous(
#     shape=torch.Size([1]),
#     space=ContinuousBox(
#         low=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#         high=Tensor(shape=torch.Size([1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#     device=cuda:0,
#     dtype=torch.float32,
#     domain=continuous)

# %%
from torchrl.envs.utils import check_env_specs

check_env_specs(env)
# Out:
# 2026-05-21 21:16:25,666 [torchrl][INFO]    check_env_specs succeeded! [END]

# %%
from torchrl.objectives.value import TD0Estimator
import torch.distributions as d
from torchrl.modules.tensordict_module.common import TensorDictModule
from torchrl.modules import NormalParamExtractor


hidden_features = 256

# policy fn
policy_net_raw = nn.Sequential(*[
    nn.LazyLinear(hidden_features),
    nn.Tanh(),
    nn.LazyLinear(hidden_features),
    nn.Tanh(),
    nn.LazyLinear(2*env.action_spec.shape[-1]),    
    NormalParamExtractor()
]).to(dev)

policy_module = TensorDictModule(
    policy_net_raw,
    in_keys=['observation'],
    out_keys=['loc', 'scale'],
)
# policy_net = nn.Sequential(*[
#     policy_module,
# ])
actor = ProbabilisticActor(
    module=policy_module,
    in_keys=['loc', 'scale'],
    out_keys=['action'],
    distribution_class=d.Normal,
    return_log_prob=True,
    spec=env.action_spec
)


critic_net = nn.Sequential(*[
    nn.LazyLinear(hidden_features),
    nn.Tanh(),
    nn.LazyLinear(hidden_features),
    nn.Tanh(),
    nn.LazyLinear(1)
]).to(dev)

value_module = TensorDictModule(
    module=critic_net,
    in_keys=['observation'],
    out_keys=['state_value']
)

# %%
clip_epsilon = 0.2
entropy_eps = 1e-3


loss_fn = ClipPPOLoss(
    actor_network=actor,
    critic_network=value_module,
        clip_epsilon=clip_epsilon,
    entropy_bonus=bool(entropy_eps),
    entropy_coeff=entropy_eps,
    # these keys match by default but we set this for completeness
    critic_coeff=1.0,
    loss_critic_type="smooth_l1",
)
loss_fn
# Out:
# ClipPPOLoss()

# %%
from torchrl.objectives import ValueEstimators

loss_fn.make_value_estimator(
    ValueEstimators.TD0,
    gamma=0.99
)

# %%
# data collector

from torchrl.data.replay_buffers.storages import LazyTensorStorage
from torchrl.data.replay_buffers.samplers import SamplerWithoutReplacement
from torchrl.collectors import Collector
from torchrl.envs.utils import ExplorationType

frames_per_batch = 5_000
total_frames = 10_000

replay_buf = ReplayBuffer(
    storage=LazyTensorStorage(max_size=frames_per_batch),
    sampler=SamplerWithoutReplacement()
)

collector = Collector(
    env,
    actor,
    frames_per_batch=frames_per_batch,
    total_frames=-1,
    device=dev,
    # replay_buffer=replay_buf,
    split_trajs=False,
    exploration_type=ExplorationType.RANDOM, 
    
)
collector
# Out:
# Collector(
#     env=TransformedEnv(
#         env=GymEnv(env=InvertedDoublePendulum-v4, batch_size=torch.Size([]), device=cuda:0),
#         transform=Compose(
#                 ObservationNorm(keys=['observation']),
#                 DoubleToFloat(in_keys=['observation'], out_keys=['observation'], in_keys_inv=[], out_keys_inv=[]),
#                 StepCounter(keys=[]))),
#     policy=ProbabilisticActor(
#         module=ModuleList(
#           (0): TensorDictModule(
#               module=Sequential(
#                 (0): Linear(in_features=11, out_features=256, bias=True)
#                 (1): Tanh()
#                 (2): Linear(in_features=256, out_features=256, bias=True)
#                 (3): Tanh()
#                 (4): Linear(in_features=256, out_features=2, bias=True)
#                 (5): NormalParamExtractor(
#                   (scale_mapping): biased_softplus()
#                 )
#               ),
#               device=cuda:0,
#               in_keys=['observation'],
#               out_keys=['loc', 'scale'])
#           (1): SafeProbabilisticModule(
#               in_keys=['loc', 'scale'],
#               out_keys=['action', 'action_log_prob'],
#               distribution_class=<class 'torch.distributions.normal.Normal'>,
#               distribution_kwargs={}),
#               default_interaction_type=deterministic),
#               num_samples=None))
#         ),
#         device=cuda:0,
#         in_keys=['observation'],
#         out_keys=['loc', 'scale', 'action', 'action_log_prob']),
#     td_out=TensorDict(
#         fields={
#             action: Tensor(sh...,
# exploration=random)

# %%
with torch.no_grad():
    dummy_data = env.reset()
    obsv = dummy_data['observation']
    obsv = obsv.to(dev)
    
    policy_net_raw(obsv)
    critic_net(obsv)

# %%
for tensordict_data in collector:
    print(tensordict_data)
    break
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#         action_log_prob: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#         collector: TensorDict(
#             fields={
#                 traj_ids: Tensor(shape=torch.Size([5000]), device=cuda:0, dtype=torch.int64, is_shared=True)},
#             batch_size=torch.Size([5000]),
#             device=cuda:0,
#             is_shared=True),
#         done: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         loc: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#         next: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#                 observation: Tensor(shape=torch.Size([5000, 11]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 reward: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 step_count: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.int64, is_shared=True),
#                 terminated: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#                 truncated: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#             batch_size=torch.Size([5000]),
#             device=cuda:0,
#             is_shared=True),
#         observation: Tensor(shape=torch.Size([5000, 11]), device=cuda:0, dtype=torch.float32, is_shared=True),
#         scale: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#         step_count: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.int64, is_shared=True),
#         terminated: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         truncated: Tensor(shape=torch.Size([5000, 1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#     batch_size=torch.Size([5000]),
#     device=cuda:0,
#     is_shared=True)

# %%
# optimizer

from torch.optim import AdamW

optim_actor = AdamW(actor.parameters(), lr=3e-4)
optim_critic = AdamW(critic_net.parameters(), lr=3e-4)

# %%
BATCH_SIZE=712
TRAIN_EPOCHS = 30
TEST_EPS = 5
TEST_MAX_STEP_SIZE = 1000
trunc = False

train_losses, objective_losses, critic_losses, entropy_losses = [], [], [], []
train_rewards = []
test_returns_all, test_step_counts_all = [], []

# train
for ep in range(TRAIN_EPOCHS):
    actor.train()
    critic_net.train()
    
    tensordict_data = next(iter(collector))
    replay_buf.extend(tensordict_data)

    loss_batch = 0
    objective_loss, critic_loss, entropy_loss = 0,0,0
    for _ in range(10):
        batch = replay_buf.sample(BATCH_SIZE)
        batch = batch.to(dev)
        
        loss_val = loss_fn(batch)
        loss = loss_val['loss_objective'] + loss_val['loss_critic'] + loss_val['loss_entropy']
        loss_batch += loss

        objective_loss += loss_val['loss_objective']
        critic_loss += loss_val['loss_critic']
        entropy_loss += loss_val['loss_entropy']

    torch.nn.utils.clip_grad_norm_(actor.parameters(), 1.0)
    torch.nn.utils.clip_grad_norm_(critic_net.parameters(), 1.0)

    optim_actor.zero_grad()
    optim_critic.zero_grad()

    loss_batch.backward()        
    
    
    optim_actor.step()
    optim_critic.step()

    train_losses.append(loss_batch.item())
    objective_losses.append(objective_loss.item())
    critic_losses.append(critic_loss.item())
    entropy_losses.append(entropy_loss.item())
    
    avg_reward = tensordict_data["next", "reward"].mean().item()
    train_rewards.append(avg_reward)

    # eval
    test_reward, test_step_c = 0,0
    actor.eval()
    with set_exploration_type(ExplorationType.DETERMINISTIC), torch.inference_mode():
        test_returns, test_step_cs = [],[]
        for _ in range(TEST_EPS):
            tensordict_data =env.rollout(TEST_MAX_STEP_SIZE, policy=actor)
    
            test_return = tensordict_data["next", "reward"].sum().item()
            test_step_c = tensordict_data["next",'step_count'].max().item()

            test_returns.append(test_return)
            test_step_cs.append(test_step_c)       
        

    test_return = sum(test_returns) / len(test_returns)
    test_step_count = sum(test_step_cs) / len(test_step_cs)

    test_returns_all.append(test_return)
    test_step_counts_all.append(test_step_count)
    
    print(f'epoch: {ep} | train step_count: {tensordict_data['step_count'].max().item()} | loss: {loss_batch.item():.5f} | loss_objective: {objective_loss.item():.5f} | loss_critic: {critic_loss.item():.5f} | loss_entropy: {entropy_loss.item():.5f} | test step_count: {test_step_count:.5f} | test return: {test_return:.5f} | reward: {avg_reward:.5f}')
# Out:
# 2026-05-17 17:22:59,027 [torchrl][INFO]    Initialized LazyTensorStorage with torch.Size([5000]) shape [END]
# epoch: 0 | train step_count: 10 | loss: -5.01416 | loss_objective: -90.86689 | loss_critic: 85.86690 | loss_entropy: -0.01417 | test step_count: 9.20000 | test return: 84.26237 | reward: 9.07945
# epoch: 1 | train step_count: 8 | loss: -5.01418 | loss_objective: -90.64018 | loss_critic: 85.64019 | loss_entropy: -0.01418 | test step_count: 9.40000 | test return: 86.45950 | reward: 9.07795
# epoch: 2 | train step_count: 7 | loss: -5.01389 | loss_objective: -90.34975 | loss_critic: 85.34975 | loss_entropy: -0.01389 | test step_count: 9.00000 | test return: 82.57462 | reward: 9.07422
# epoch: 3 | train step_count: 8 | loss: -5.01387 | loss_objective: -90.31416 | loss_critic: 85.31417 | loss_entropy: -0.01387 | test step_count: 9.00000 | test return: 82.54474 | reward: 9.06847
# epoch: 4 | train step_count: 7 | loss: -5.01377 | loss_objective: -90.01030 | loss_critic: 85.01031 | loss_entropy: -0.01377 | test step_count: 9.00000 | test return: 82.59809 | reward: 9.07322
# epoch: 5 | train step_count: 8 | loss: -5.01382 | loss_objective: -89.98719 | loss_critic: 84.98719 | loss_entropy: -0.01382 | test step_count: 8.80000 | test return: 80.74020 | reward: 9.06769
# epoch: 6 | train step_count: 9 | loss: -5.01370 | loss_objective: -89.45236 | loss_critic: 84.45236 | loss_entropy: -0.01370 | test step_count: 8.40000 | test return: 76.80991 | reward: 9.07648
# epoch: 7 | train step_count: 6 | loss: -5.01352 | loss_objective: -89.53442 | loss_critic: 84.53442 | loss_entropy: -0.01353 | test step_count: 8.00000 | test return: 73.18843 | reward: 9.07757
# epoch: 8 | train step_count: 12 | loss: -5.01341 | loss_objective: -89.44415 | loss_critic: 84.44415 | loss_entropy: -0.01342 | test step_count: 8.80000 | test return: 80.79264 | reward: 9.07534
# epoch: 9 | train step_count: 9 | loss: -5.01325 | loss_objective: -89.16652 | loss_critic: 84.16651 | loss_entropy: -0.01325 | test step_count: 9.40000 | test return: 86.09699 | reward: 9.07427
# epoch: 10 | train step_count: 6 | loss: -5.01320 | loss_objective: -88.97116 | loss_critic: 83.97116 | loss_entropy: -0.01320 | test step_count: 9.80000 | test return: 90.26943 | reward: 9.08118
# epoch: 11 | train step_count: 17 | loss: -5.01320 | loss_objective: -89.03017 | loss_critic: 84.03017 | loss_entropy: -0.01320 | test step_count: 12.20000 | test return: 112.74736 | reward: 9.08027
# epoch: 12 | train step_count: 9 | loss: -5.01315 | loss_objective: -88.68722 | loss_critic: 83.68723 | loss_entropy: -0.01315 | test step_count: 10.60000 | test return: 97.58391 | reward: 9.08547
# epoch: 13 | train step_count: 9 | loss: -5.01328 | loss_objective: -88.79219 | loss_critic: 83.79219 | loss_entropy: -0.01328 | test step_count: 10.00000 | test return: 92.01820 | reward: 9.09089
# epoch: 14 | train step_count: 13 | loss: -5.01342 | loss_objective: -88.59673 | loss_critic: 83.59673 | loss_entropy: -0.01343 | test step_count: 12.60000 | test return: 116.39629 | reward: 9.09325
# epoch: 15 | train step_count: 10 | loss: -5.01374 | loss_objective: -88.31924 | loss_critic: 83.31924 | loss_entropy: -0.01374 | test step_count: 14.00000 | test return: 129.35621 | reward: 9.09428
# epoch: 16 | train step_count: 10 | loss: -5.01373 | loss_objective: -88.32651 | loss_critic: 83.32651 | loss_entropy: -0.01373 | test step_count: 12.00000 | test return: 110.72451 | reward: 9.09865
# epoch: 17 | train step_count: 11 | loss: -5.01365 | loss_objective: -88.38841 | loss_critic: 83.38841 | loss_entropy: -0.01365 | test step_count: 11.80000 | test return: 109.07721 | reward: 9.10200
# epoch: 18 | train step_count: 12 | loss: -5.01369 | loss_objective: -88.26859 | loss_critic: 83.26859 | loss_entropy: -0.01369 | test step_count: 10.80000 | test return: 99.73026 | reward: 9.10454
# epoch: 19 | train step_count: 12 | loss: -5.01364 | loss_objective: -88.01194 | loss_critic: 83.01194 | loss_entropy: -0.01364 | test step_count: 12.80000 | test return: 118.53846 | reward: 9.10420
# epoch: 20 | train step_count: 10 | loss: -5.01370 | loss_objective: -87.81405 | loss_critic: 82.81406 | loss_entropy: -0.01370 | test step_count: 11.60000 | test return: 107.29014 | reward: 9.10957
# epoch: 21 | train step_count: 15 | loss: -5.01360 | loss_objective: -87.91272 | loss_critic: 82.91272 | loss_entropy: -0.01360 | test step_count: 13.60000 | test return: 125.85886 | reward: 9.11616
# epoch: 22 | train step_count: 12 | loss: -5.01380 | loss_objective: -87.58643 | loss_critic: 82.58643 | loss_entropy: -0.01380 | test step_count: 12.00000 | test return: 110.92658 | reward: 9.12003
# epoch: 23 | train step_count: 12 | loss: -5.01363 | loss_objective: -87.72346 | loss_critic: 82.72348 | loss_entropy: -0.01363 | test step_count: 13.60000 | test return: 125.69490 | reward: 9.11961
# epoch: 24 | train step_count: 17 | loss: -5.01361 | loss_objective: -87.47227 | loss_critic: 82.47227 | loss_entropy: -0.01361 | test step_count: 16.40000 | test return: 151.67667 | reward: 9.12403
# epoch: 25 | train step_count: 14 | loss: -5.01356 | loss_objective: -87.12032 | loss_critic: 82.12032 | loss_entropy: -0.01356 | test step_count: 13.80000 | test return: 127.60842 | reward: 9.12435
# epoch: 26 | train step_count: 16 | loss: -5.01353 | loss_objective: -87.06174 | loss_critic: 82.06174 | loss_entropy: -0.01354 | test step_count: 13.60000 | test return: 125.87440 | reward: 9.13433
# epoch: 27 | train step_count: 13 | loss: -5.01357 | loss_objective: -86.97611 | loss_critic: 81.97611 | loss_entropy: -0.01357 | test step_count: 12.40000 | test return: 114.65943 | reward: 9.13548
# epoch: 28 | train step_count: 13 | loss: -5.01346 | loss_objective: -87.08190 | loss_critic: 82.08191 | loss_entropy: -0.01347 | test step_count: 13.80000 | test return: 127.85510 | reward: 9.14194
# epoch: 29 | train step_count: 10 | loss: -5.01335 | loss_objective: -86.89624 | loss_critic: 81.89625 | loss_entropy: -0.01336 | test step_count: 17.20000 | test return: 159.58600 | reward: 9.14044

# %%
import matplotlib.pyplot as plt

plt.plot(train_rewards)

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses)

# %%
fig = plt.figure(figsize=(12, 4))

import numpy as np

t = np.arange(0, TRAIN_EPOCHS)

ax1 = fig.add_subplot(1, 3,1)
ax2 = fig.add_subplot(1, 3,2)
ax3 = fig.add_subplot(1, 3,3)

ax1.plot(t, objective_losses)
ax2.plot(t,critic_losses)
ax3.plot(t,entropy_losses)

ax1.set_title('Obj loss')
ax2.set_title('Critic loss')
ax3.set_title('entropy loss')
plt.show()

# %%
fig = plt.figure(figsize=(12, 4))

import numpy as np

t = np.arange(0, len(test_returns_all))

ax1 = fig.add_subplot(1, 2,1)
ax2 = fig.add_subplot(1, 2,2)

ax1.plot(t, test_returns_all)
ax2.plot(t,test_step_counts_all)

ax1.set_title('Test Returns')
ax2.set_title('Test steps')
plt.show()

# %%
# test

with torch.no_grad():
    obsv = env.reset()
    #  ...

# %%
env.close()
